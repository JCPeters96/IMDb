# %% [markdown]
# ## Import packages

# %%
import requests
from bs4 import BeautifulSoup
import time
from time import sleep
import pandas as pd
import numpy as np

url = 'https://www.imdb.com/search/title/?groups=top_1000&sort=user_rating,desc&count=100&start=001&ref_=adv_nxt'
res = requests.get(url)
soup = BeautifulSoup(res.text, "html.parser")

# %% [markdown]
# ## Create page urls

# %%
def generate_page_urls(base_url, num_pages):
    page_urls = []
        
    for counter in range(0, num_pages + 1):
        full_url = base_url + str(counter) + '01&ref_=adv_nxt'
        page_urls.append(full_url)
        
    return page_urls

# %% [markdown]
# ## Extract data

# %%
def extract_movie_data(page_urls):
    movie_list = []
    
    for page_url in page_urls:
        res = requests.get(page_url)
        soup= BeautifulSoup(res.text, "html.parser")
        movies = soup.find_all(class_= "lister-item mode-advanced")
        
        for movie in movies:
            movie_rank = movie.find(class_="lister-item-index unbold text-primary").text
            movie_url = "https://imdb.com" + movie.find("a").attrs["href"]
            movie_title = movie.find('h3').find('a').text
            movie_date = movie.find(class_="lister-item-year text-muted unbold").text
            movie_date = movie_date.replace('(','').replace(')','')
            movie_rating = movie.find('strong').text
            movie_meta = movie.find('span', class_ = 'metascore favorable')
            movie_genre = movie.find(class_="genre").text
            movie_genre = movie_genre.replace('\n','').replace("  ", "")
            movie_runtime = movie.find(class_="runtime").text
            num_votes = movie.find_all('span', attrs={'name': 'nv'})
            number_votes = num_votes[0].text
            movie_grosses = num_votes[1].text if len(num_votes) > 1 else 'N/A'
            director = movie.find('p',class_= '').find_all('a')[0].text
            actor_1 = movie.find('p', class_ = '').find_all('a')[1].text
            actor_2 = movie.find('p', class_ = '').find_all('a')[2].text
            actor_3 = movie.find('p', class_ = '').find_all('a')[3].text
            actor_4 = movie.find('p', class_ = '').find_all('a')[4].text
            summary = movie.find('p').find(class_="text-muted")
            
                    
            movie_list.append({"rank": movie_rank,
                              "movie url": movie_url,
                              "title" : movie_title,
                              "date" : movie_date,
                              "IMDb rating" : movie_rating,
                              "metascore" : movie_meta,
                              "genre" : movie_genre,
                               "director" : director,
                              "actor_1": actor_1,
                              "actor_2" : actor_2,
                              "actor_3" : actor_3,
                              "actor_4" : actor_4,
                              "runtime" : movie_runtime,
                              "votes" : number_votes,
                              "gross" : movie_grosses,
                              "summary" : summary})
            
        #sleep (1)
            
    return movie_list

# %%
base_url = 'https://www.imdb.com/search/title/?groups=top_1000&sort=user_rating,desc&count=100&start='
num_pages = 0
page_urls =  generate_page_urls(base_url, num_pages)
movie_list = extract_movie_data(page_urls)
movie_list
# Out:
# [{'rank': '1.',
#   'movie url': 'https://imdb.com/title/tt0111161/',
#   'title': 'The Shawshank Redemption',
#   'date': '1994',
#   'IMDb rating': '9.3',
#   'metascore': <span class="metascore favorable">80        </span>,
#   'genre': 'Drama',
#   'director': 'Frank Darabont',
#   'actor_1': 'Tim Robbins',
#   'actor_2': 'Morgan Freeman',
#   'actor_3': 'Bob Gunton',
#   'actor_4': 'William Sadler',
#   'runtime': '142 min',
#   'votes': '2,388,501',
#   'gross': '$28.34M',
#   'summary': None},
#  {'rank': '2.',
#   'movie url': 'https://imdb.com/title/tt0068646/',
#   'title': 'The Godfather',
#   'date': '1972',
#   'IMDb rating': '9.2',
#   'metascore': <span class="metascore favorable">100        </span>,
#   'genre': 'Crime, Drama',
#   'director': 'Francis Ford Coppola',
#   'actor_1': 'Marlon Brando',
#   'actor_2': 'Al Pacino',
#   'actor_3': 'James Caan',
#   'actor_4': 'Diane Keaton',
#   'runtime': '175 min',
#   'votes': '1,655,142',
#   'gross': '$134.97M',
#   'summary': None},
#  {'rank': '3.',
#   'movie url': 'https://imdb.com/title/tt10189514/',
#   'title': 'Soorarai Pottru',
#   'date': '2020',
#   'IMDb rating': '9.1',
#   'metascore': None,
#   'genre': 'Drama',
#   'director': 'Sudha Kongara',
#   'actor_1': 'Suriya',
#   'actor_2': 'Madhavan',
#   'actor_3': 'Paresh Rawal',
#   'actor_4': 'Aparna Balamurali',
#   'runtime': '153 min',
#   'votes': '60,614',
#   'gross': 'N/A',
#   'summary': None},
#  {'rank': '4.',
#   'movie url': 'https://imdb.com/title/tt0468569/',
#   'title': 'The Dark Knight',
#   'date': '2008',
#   'IMDb rating': '9.0',
#   'metascore': <span class="metascore favorable">84        </span>,
#   'genre': 'Action, Crime, Drama',
#   'director': 'Christopher Nolan',
#   'actor_1': 'Christian Bale',
#   'actor_2': 'Heath Ledger',
#   'actor_3': 'Aaron Eckhart',
#   'actor_4': 'Michael Caine',
#   'runtime': '152 min',
#   'votes': '2,351,178',
#   'gross': '$534.86M',
#   'summary': None},
#  {'rank': '5.',
#   'movie url': 'https://imdb.com/title/tt0071562/',
#   'title': 'The Godfather: Part II',
#   'date': '1974',
#   'IMDb rating': '9.0',
#   'metascore': <span class="metascore favorable">90        </span>,
#   'genre': 'Crime, Drama',
#   'director': 'Francis Ford Coppola',
#   'actor_1': 'Al Pacino',
#   'actor_2': 'Robert De Niro',
#   'actor_3': 'Robert Duvall',
#   'actor_4': 'Diane Keaton',
#   'runtime': '202 min',
#   'votes': '1,151,039',
#   'gross': '$57.30M',
#   'summary': None},
#  {'rank': '6.',
#   'movie url': 'https://imdb.com/title/tt0050083/',
#   'title': '12 Angry Men',
#   'date': '1957',
#   'IMDb rating': '9.0',
#   'metascore': <span class="metascore favorable">96        </span>,
#   'genre': 'Crime, Drama',
#   'director': 'Sidney Lumet',
#   'actor_1': 'Henry Fonda',
#   'actor_2': 'Lee J. Cobb',
#   'actor_3': 'Martin Balsam',
#   'actor_4': 'John Fiedler',
#   'runtime': '96 min',
#   'votes': '704,726',
#   'gross': '$4.36M',
#   'summary': None},
#  {'rank': '7.',
#   'movie url': 'https://imdb.com/title/tt0167260/',
#   'title': 'The Lord of the Rings: The Return of the King',
#   'date': '2003',
#   'IMDb rating': '8.9',
#   'metascore': <span class="metascore favorable">94        </span>,
#   'genre': 'Action, Adventure, Drama',
#   'director': 'Peter Jackson',
#   'actor_1': 'Elijah Wood',
#   'actor_2': 'Viggo Mortensen',
#   'actor_3': 'Ian McKellen',
#   'actor_4': 'Orlando Bloom',
#   'runtime': '201 min',
#   'votes': '1,670,005',
#   'gross': '$377.85M',
#   'summary': None},
#  {'rank': '8.',
#   'movie url': 'https://imdb.com/title/tt0110912/',
#   'title': 'Pulp Fiction',
#   'date': '1994',
#   'IMDb rating': '8.9',
#   'metascore': <span class="metascore favorable">94        </span>,
#   'genre': 'Crime, Drama',
#   'director': 'Quentin Tarantino',
#   'actor_1': 'John Travolta',
#   'actor_2': 'Uma Thurman',
#   'actor_3': 'Samuel L. Jackson',
#   'actor_4': 'Bruce Willis',
#   'runtime': '154 min',
#   'votes': '1,859,783',
#   'gross': '$107.93M',
#   'summary': None},
#  {'rank': '9.',
#   'movie url': 'https://imdb.com/title/tt0108052/',
#   'title': "Schindler's List",
#   'date': '1993',
#   'IMDb rating': '8.9',
#   'metascore': <span class="metascore favorable">94        </span>,
#   'genre': 'Biography, Drama, History',
#   'director': 'Steven Spielberg',
#   'actor_1': 'Liam Neeson',
#   'actor_2': 'Ralph Fiennes',
#   'actor_3': 'Ben Kingsley',
#   'actor_4': 'Caroline Goodall',
#   'runtime': '195 min',
#   'votes': '1,234,333',
#   'gross': '$96.90M',
#   'summary': None},
#  {'rank': '10.',
#   'movie url': 'https://imdb.com/title/tt1375666/',
#   'title': 'Inception',
#   'date': '2010',
#   'IMDb rating': '8.8',
#   'metascore': <span class="metascore favorable">74        </span>,
#   'genre': 'Action, Adventure, Sci-Fi',
#   'director': 'Christopher Nolan',
#   'actor_1': 'Leonardo DiCaprio',
#   'actor_2': 'Joseph Gordon-Levitt',
#   'actor_3': 'Elliot Page',
#   'actor_4': 'Ken Watanabe',
#   'runtime': '148 min',
#   'votes': '2,109,811',
#   'gross': '$292.58M',
#   'summary': None},
#  {'rank': '11.',
#   'movie url': 'https://imdb.com/title/tt0137523/',
#   'title': 'Fight Club',
#   'date': '1999',
#   'IMDb rating': '8.8',
#   'metascore': <span class="metascore favorable">66        </span>,
#   'genre': 'Drama',
#   'director': 'David Fincher',
#   'actor_1': 'Brad Pitt',
#   'actor_2': 'Edward Norton',
#   'actor_3': 'Meat Loaf',
#   'actor_4': 'Zach Grenier',
#   'runtime': '139 min',
#   'votes': '1,889,130',
#   'gross': '$37.03M',
#   'summary': None},
#  {'rank': '12.',
#   'movie url': 'https://imdb.com/title/tt0120737/',
#   'title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'date': '2001',
#   'IMDb rating': '8.8',
#   'metascore': <span class="metascore favorable">92        </span>,
#   'genre': 'Action, Adventure, Drama',
#   'director': 'Peter Jackson',
#   'actor_1': 'Elijah Wood',
#   'actor_2': 'Ian McKellen',
#   'actor_3': 'Orlando Bloom',
#   'actor_4': 'Sean Bean',
#   'runtime': '178 min',
#   'votes': '1,690,787',
#   'gross': '$315.54M',
#   'summary': None},
#  {'rank': '13.',
#   'movie url': 'https://imdb.com/title/tt0109830/',
#   'title': 'Forrest Gump',
#   'date': '1994',
#   'IMDb rating': '8.8',
#   'metascore': <span class="metascore favorable">82        </span>,
#   'genre': 'Drama, Romance',
#   'director': 'Robert Zemeckis',
#   'actor_1': 'Tom Hanks',
#   'actor_2': 'Robin Wright',
#   'actor_3': 'Gary Sinise',
#   'actor_4': 'Sally Field',
#   'runtime': '142 min',
#   'votes': '1,847,897',
#   'gross': '$330.25M',
#   'summary': None},
#  {'rank': '14.',
#   'movie url': 'https://imdb.com/title/tt0060196/',
#   'title': 'The Good, the Bad and the Ugly',
#   'date': '1966',
#   'IMDb rating': '8.8',
#   'metascore': <span class="metascore favorable">90        </span>,
#   'genre': 'Western',
#   'director': 'Sergio Leone',
#   'actor_1': 'Clint Eastwood',
#   'actor_2': 'Eli Wallach',
#   'actor_3': 'Lee Van Cleef',
#   'actor_4': 'Aldo Giuffrè',
#   'runtime': '161 min',
#   'votes': '699,418',
#   'gross': '$6.10M',
#   'summary': None},
#  {'rank': '15.',
#   'movie url': 'https://imdb.com/title/tt0167261/',
#   'title': 'The Lord of the Rings: The Two Towers',
#   'date': '2002',
#   'IMDb rating': '8.7',
#   'metascore': <span class="metascore favorable">87        </span>,
#   'genre': 'Action, Adventure, Drama',
#   'director': 'Peter Jackson',
#   'actor_1': 'Elijah Wood',
#   'actor_2': 'Ian McKellen',
#   'actor_3': 'Viggo Mortensen',
#   'actor_4': 'Orlando Bloom',
#   'runtime': '179 min',
#   'votes': '1,510,337',
#   'gross': '$342.55M',
#   'summary': None},
#  {'rank': '16.',
#   'movie url': 'https://imdb.com/title/tt0133093/',
#   'title': 'The Matrix',
#   'date': '1999',
#   'IMDb rating': '8.7',
#   'metascore': <span class="metascore favorable">73        </span>,
#   'genre': 'Action, Sci-Fi',
#   'director': 'Lana Wachowski',
#   'actor_1': 'Lilly Wachowski',
#   'actor_2': 'Keanu Reeves',
#   'actor_3': 'Laurence Fishburne',
#   'actor_4': 'Carrie-Anne Moss',
#   'runtime': '136 min',
#   'votes': '1,707,668',
#   'gross': '$171.48M',
#   'summary': None},
#  {'rank': '17.',
#   'movie url': 'https://imdb.com/title/tt0099685/',
#   'title': 'Goodfellas',
#   'date': '1990',
#   'IMDb rating': '8.7',
#   'metascore': <span class="metascore favorable">90        </span>,
#   'genre': 'Biography, Crime, Drama',
#   'director': 'Martin Scorsese',
#   'actor_1': 'Robert De Niro',
#   'actor_2': 'Ray Liotta',
#   'actor_3': 'Joe Pesci',
#   'actor_4': 'Lorraine Bracco',
#   'runtime': '146 min',
#   'votes': '1,040,959',
#   'gross': '$46.84M',
#   'summary': None},
#  {'rank': '18.',
#   'movie url': 'https://imdb.com/title/tt0080684/',
#   'title': 'Star Wars: Episode V - The Empire Strikes Back',
#   'date': '1980',
#   'IMDb rating': '8.7',
#   'metascore': <span class="metascore favorable">82        </span>,
#   'genre': 'Action, Adventure, Fantasy',
#   'director': 'Irvin Kershner',
#   'actor_1': 'Mark Hamill',
#   'actor_2': 'Harrison Ford',
#   'actor_3': 'Carrie Fisher',
#   'actor_4': 'Billy Dee Williams',
#   'runtime': '124 min',
#   'votes': '1,177,280',
#   'gross': '$290.48M',
#   'summary': None},
#  {'rank': '19.',
#   'movie url': 'https://imdb.com/title/tt0073486/',
#   'title': "One Flew Over the Cuckoo's Nest",
#   'date': '1975',
#   'IMDb rating': '8.7',
#   'metascore': <span class="metascore favorable">84        </span>,
#   'genre': 'Drama',
#   'director': 'Milos Forman',
#   'actor_1': 'Jack Nicholson',
#   'actor_2': 'Louise Fletcher',
#   'actor_3': 'Michael Berryman',
#   'actor_4': 'Peter Brocco',
#   'runtime': '133 min',
#   'votes': '932,177',
#   'gross': '$112.00M',
#   'summary': None},
#  {'rank': '20.',
#   'movie url': 'https://imdb.com/title/tt6751668/',
#   'title': 'Gisaengchung',
#   'date': '2019',
#   'IMDb rating': '8.6',
#   'metascore': <span class="metascore favorable">96        </span>,
#   'genre': 'Comedy, Drama, Thriller',
#   'director': 'Bong Joon Ho',
#   'actor_1': 'Kang-ho Song',
#   'actor_2': 'Sun-kyun Lee',
#   'actor_3': 'Yeo-jeong Cho',
#   'actor_4': 'Woo-sik Choi',
#   'runtime': '132 min',
#   'votes': '603,769',
#   'gross': '$53.37M',
#   'summary': None},
#  {'rank': '21.',
#   'movie url': 'https://imdb.com/title/tt0816692/',
#   'title': 'Interstellar',
#   'date': '2014',
#   'IMDb rating': '8.6',
#   'metascore': <span class="metascore favorable">74        </span>,
#   'genre': 'Adventure, Drama, Sci-Fi',
#   'director': 'Christopher Nolan',
#   'actor_1': 'Matthew McConaughey',
#   'actor_2': 'Anne Hathaway',
#   'actor_3': 'Jessica Chastain',
#   'actor_4': 'Mackenzie Foy',
#   'runtime': '169 min',
#   'votes': '1,554,439',
#   'gross': '$188.02M',
#   'summary': None},
#  {'rank': '22.',
#   'movie url': 'https://imdb.com/title/tt0317248/',
#   'title': 'Cidade de Deus',
#   'date': '2002',
#   'IMDb rating': '8.6',
#   'metascore': <span class="metascore favorable">79        </span>,
#   'genre': 'Crime, Drama',
#   'director': 'Fernando Meirelles',
#   'actor_1': 'Kátia Lund',
#   'actor_2': 'Alexandre Rodrigues',
#   'actor_3': 'Leandro Firmino',
#   'actor_4': 'Matheus Nachtergaele',
#   'runtime': '130 min',
#   'votes': '708,546',
#   'gross': '$7.56M',
#   'summary': None},
#  {'rank': '23.',
#   'movie url': 'https://imdb.com/title/tt0245429/',
#   'title': 'Spirited Away',
#   'date': '2001',
#   'IMDb rating': '8.6',
#   'metascore': <span class="metascore favorable">96        </span>,
#   'genre': 'Animation, Adventure, Family',
#   'director': 'Hayao Miyazaki',
#   'actor_1': 'Daveigh Chase',
#   'actor_2': 'Suzanne Pleshette',
#   'actor_3': 'Miyu Irino',
#   'actor_4': 'Rumi Hiiragi',
#   'runtime': '125 min',
#   'votes': '669,181',
#   'gross': '$10.06M',
#   'summary': None},
#  {'rank': '24.',
#   'movie url': 'https://imdb.com/title/tt0120815/',
#   'title': 'Saving Private Ryan',
#   'date': '1998',
#   'IMDb rating': '8.6',
#   'metascore': <span class="metascore favorable">91        </span>,
#   'genre': 'Drama, War',
#   'director': 'Steven Spielberg',
#   'actor_1': 'Tom Hanks',
#   'actor_2': 'Matt Damon',
#   'actor_3': 'Tom Sizemore',
#   'actor_4': 'Edward Burns',
#   'runtime': '169 min',
#   'votes': '1,260,378',
#   'gross': '$216.54M',
#   'summary': None},
#  {'rank': '25.',
#   'movie url': 'https://imdb.com/title/tt0120689/',
#   'title': 'The Green Mile',
#   'date': '1999',
#   'IMDb rating': '8.6',
#   'metascore': <span class="metascore favorable">61        </span>,
#   'genre': 'Crime, Drama, Fantasy',
#   'director': 'Frank Darabont',
#   'actor_1': 'Tom Hanks',
#   'actor_2': 'Michael Clarke Duncan',
#   'actor_3': 'David Morse',
#   'actor_4': 'Bonnie Hunt',
#   'runtime': '189 min',
#   'votes': '1,171,569',
#   'gross': '$136.80M',
#   'summary': None},
#  {'rank': '26.',
#   'movie url': 'https://imdb.com/title/tt0118799/',
#   'title': 'Het leven is mooi',
#   'date': '1997',
#   'IMDb rating': '8.6',
#   'metascore': None,
#   'genre': 'Comedy, Drama, Romance',
#   'director': 'Roberto Benigni',
#   'actor_1': 'Roberto Benigni',
#   'actor_2': 'Nicoletta Braschi',
#   'actor_3': 'Giorgio Cantarini',
#   'actor_4': 'Giustino Durano',
#   'runtime': '116 min',
#   'votes': '635,792',
#   'gross': '$57.60M',
#   'summary': None},
#  {'rank': '27.',
#   'movie url': 'https://imdb.com/title/tt0114369/',
#   'title': 'Seven',
#   'date': '1995',
#   'IMDb rating': '8.6',
#   'metascore': <span class="metascore favorable">65        </span>,
#   'genre': 'Crime, Drama, Mystery',
#   'director': 'David Fincher',
#   'actor_1': 'Morgan Freeman',
#   'actor_2': 'Brad Pitt',
#   'actor_3': 'Kevin Spacey',
#   'actor_4': 'Andrew Kevin Walker',
#   'runtime': '127 min',
#   'votes': '1,474,515',
#   'gross': '$100.13M',
#   'summary': None},
#  {'rank': '28.',
#   'movie url': 'https://imdb.com/title/tt0102926/',
#   'title': 'The Silence of the Lambs',
#   'date': '1991',
#   'IMDb rating': '8.6',
#   'metascore': <span class="metascore favorable">85        </span>,
#   'genre': 'Crime, Drama, Thriller',
#   'director': 'Jonathan Demme',
#   'actor_1': 'Jodie Foster',
#   'actor_2': 'Anthony Hopkins',
#   'actor_3': 'Lawrence A. Bonney',
#   'actor_4': 'Kasi Lemmons',
#   'runtime': '118 min',
#   'votes': '1,296,296',
#   'gross': '$130.74M',
#   'summary': None},
#  {'rank': '29.',
#   'movie url': 'https://imdb.com/title/tt0076759/',
#   'title': 'Star Wars: Episode IV - A New Hope',
#   'date': '1977',
#   'IMDb rating': '8.6',
#   'metascore': <span class="metascore favorable">90        </span>,
#   'genre': 'Action, Adventure, Fantasy',
#   'director': 'George Lucas',
#   'actor_1': 'Mark Hamill',
#   'actor_2': 'Harrison Ford',
#   'actor_3': 'Carrie Fisher',
#   'actor_4': 'Alec Guinness',
#   'runtime': '121 min',
#   'votes': '1,249,364',
#   'gross': '$322.74M',
#   'summary': None},
#  {'rank': '30.',
#   'movie url': 'https://imdb.com/title/tt0056058/',
#   'title': 'Seppuku',
#   'date': '1962',
#   'IMDb rating': '8.6',
#   'metascore': <span class="metascore favorable">85        </span>,
#   'genre': 'Action, Drama, Mystery',
#   'director': 'Masaki Kobayashi',
#   'actor_1': 'Tatsuya Nakadai',
#   'actor_2': 'Akira Ishihama',
#   'actor_3': 'Shima Iwashita',
#   'actor_4': 'Tetsurô Tanba',
#   'runtime': '133 min',
#   'votes': '44,765',
#   'gross': 'N/A',
#   'summary': None},
#  {'rank': '31.',
#   'movie url': 'https://imdb.com/title/tt0047478/',
#   'title': 'Shichinin no samurai',
#   'date': '1954',
#   'IMDb rating': '8.6',
#   'metascore': <span class="metascore favorable">98        </span>,
#   'genre': 'Action, Adventure, Drama',
#   'director': 'Akira Kurosawa',
#   'actor_1': 'Toshirô Mifune',
#   'actor_2': 'Takashi Shimura',
#   'actor_3': 'Keiko Tsushima',
#   'actor_4': 'Yukiko Shimazaki',
#   'runtime': '207 min',
#   'votes': '320,904',
#   'gross': '$0.27M',
#   'summary': None},
#  {'rank': '32.',
#   'movie url': 'https://imdb.com/title/tt0038650/',
#   'title': "It's a Wonderful Life",
#   'date': '1946',
#   'IMDb rating': '8.6',
#   'metascore': <span class="metascore favorable">89        </span>,
#   'genre': 'Drama, Family, Fantasy',
#   'director': 'Frank Capra',
#   'actor_1': 'James Stewart',
#   'actor_2': 'Donna Reed',
#   'actor_3': 'Lionel Barrymore',
#   'actor_4': 'Thomas Mitchell',
#   'runtime': '130 min',
#   'votes': '411,963',
#   'gross': 'N/A',
#   'summary': None},
#  {'rank': '33.',
#   'movie url': 'https://imdb.com/title/tt8503618/',
#   'title': 'Hamilton',
#   'date': '2020',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">90        </span>,
#   'genre': 'Biography, Drama, History',
#   'director': 'Thomas Kail',
#   'actor_1': 'Lin-Manuel Miranda',
#   'actor_2': 'Phillipa Soo',
#   'actor_3': 'Leslie Odom Jr.',
#   'actor_4': 'Renée Elise Goldsberry',
#   'runtime': '160 min',
#   'votes': '63,922',
#   'gross': 'N/A',
#   'summary': None},
#  {'rank': '34.',
#   'movie url': 'https://imdb.com/title/tt7060344/',
#   'title': 'Ratsasan',
#   'date': '2018',
#   'IMDb rating': '8.5',
#   'metascore': None,
#   'genre': 'Action, Crime, Thriller',
#   'director': 'Ram Kumar',
#   'actor_1': 'Vishnu Vishal',
#   'actor_2': 'Amala Paul',
#   'actor_3': 'Radha Ravi',
#   'actor_4': 'Sangili Murugan',
#   'runtime': '170 min',
#   'votes': '28,283',
#   'gross': 'N/A',
#   'summary': None},
#  {'rank': '35.',
#   'movie url': 'https://imdb.com/title/tt2582802/',
#   'title': 'Whiplash',
#   'date': '2014',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">88        </span>,
#   'genre': 'Drama, Music',
#   'director': 'Damien Chazelle',
#   'actor_1': 'Miles Teller',
#   'actor_2': 'J.K. Simmons',
#   'actor_3': 'Melissa Benoist',
#   'actor_4': 'Paul Reiser',
#   'runtime': '106 min',
#   'votes': '736,949',
#   'gross': '$13.09M',
#   'summary': None},
#  {'rank': '36.',
#   'movie url': 'https://imdb.com/title/tt1675434/',
#   'title': 'The Intouchables',
#   'date': '2011',
#   'IMDb rating': '8.5',
#   'metascore': None,
#   'genre': 'Biography, Comedy, Drama',
#   'director': 'Olivier Nakache',
#   'actor_1': 'Éric Toledano',
#   'actor_2': 'François Cluzet',
#   'actor_3': 'Omar Sy',
#   'actor_4': 'Anne Le Ny',
#   'runtime': '112 min',
#   'votes': '777,095',
#   'gross': '$13.18M',
#   'summary': None},
#  {'rank': '37.',
#   'movie url': 'https://imdb.com/title/tt0482571/',
#   'title': 'The Prestige',
#   'date': '2006',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">66        </span>,
#   'genre': 'Drama, Mystery, Sci-Fi',
#   'director': 'Christopher Nolan',
#   'actor_1': 'Christian Bale',
#   'actor_2': 'Hugh Jackman',
#   'actor_3': 'Scarlett Johansson',
#   'actor_4': 'Michael Caine',
#   'runtime': '130 min',
#   'votes': '1,213,522',
#   'gross': '$53.09M',
#   'summary': None},
#  {'rank': '38.',
#   'movie url': 'https://imdb.com/title/tt0407887/',
#   'title': 'The Departed',
#   'date': '2006',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">85        </span>,
#   'genre': 'Crime, Drama, Thriller',
#   'director': 'Martin Scorsese',
#   'actor_1': 'Leonardo DiCaprio',
#   'actor_2': 'Matt Damon',
#   'actor_3': 'Jack Nicholson',
#   'actor_4': 'Mark Wahlberg',
#   'runtime': '151 min',
#   'votes': '1,211,158',
#   'gross': '$132.38M',
#   'summary': None},
#  {'rank': '39.',
#   'movie url': 'https://imdb.com/title/tt0253474/',
#   'title': 'The Pianist',
#   'date': '2002',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">85        </span>,
#   'genre': 'Biography, Drama, Music',
#   'director': 'Roman Polanski',
#   'actor_1': 'Adrien Brody',
#   'actor_2': 'Thomas Kretschmann',
#   'actor_3': 'Frank Finlay',
#   'actor_4': 'Emilia Fox',
#   'runtime': '150 min',
#   'votes': '747,269',
#   'gross': '$32.57M',
#   'summary': None},
#  {'rank': '40.',
#   'movie url': 'https://imdb.com/title/tt0172495/',
#   'title': 'Gladiator',
#   'date': '2000',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">67        </span>,
#   'genre': 'Action, Adventure, Drama',
#   'director': 'Ridley Scott',
#   'actor_1': 'Russell Crowe',
#   'actor_2': 'Joaquin Phoenix',
#   'actor_3': 'Connie Nielsen',
#   'actor_4': 'Oliver Reed',
#   'runtime': '155 min',
#   'votes': '1,364,095',
#   'gross': '$187.71M',
#   'summary': None},
#  {'rank': '41.',
#   'movie url': 'https://imdb.com/title/tt0120586/',
#   'title': 'American History X',
#   'date': '1998',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">62        </span>,
#   'genre': 'Drama',
#   'director': 'Tony Kaye',
#   'actor_1': 'Edward Norton',
#   'actor_2': 'Edward Furlong',
#   'actor_3': "Beverly D'Angelo",
#   'actor_4': 'Jennifer Lien',
#   'runtime': '119 min',
#   'votes': '1,048,292',
#   'gross': '$6.72M',
#   'summary': None},
#  {'rank': '42.',
#   'movie url': 'https://imdb.com/title/tt0114814/',
#   'title': 'The Usual Suspects',
#   'date': '1995',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">77        </span>,
#   'genre': 'Crime, Mystery, Thriller',
#   'director': 'Bryan Singer',
#   'actor_1': 'Kevin Spacey',
#   'actor_2': 'Gabriel Byrne',
#   'actor_3': 'Chazz Palminteri',
#   'actor_4': 'Stephen Baldwin',
#   'runtime': '106 min',
#   'votes': '1,006,179',
#   'gross': '$23.34M',
#   'summary': None},
#  {'rank': '43.',
#   'movie url': 'https://imdb.com/title/tt0110413/',
#   'title': 'Léon',
#   'date': '1994',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">64        </span>,
#   'genre': 'Action, Crime, Drama',
#   'director': 'Luc Besson',
#   'actor_1': 'Jean Reno',
#   'actor_2': 'Gary Oldman',
#   'actor_3': 'Natalie Portman',
#   'actor_4': 'Danny Aiello',
#   'runtime': '110 min',
#   'votes': '1,054,661',
#   'gross': '$19.50M',
#   'summary': None},
#  {'rank': '44.',
#   'movie url': 'https://imdb.com/title/tt0110357/',
#   'title': 'The Lion King',
#   'date': '1994',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">88        </span>,
#   'genre': 'Animation, Adventure, Drama',
#   'director': 'Roger Allers',
#   'actor_1': 'Rob Minkoff',
#   'actor_2': 'Matthew Broderick',
#   'actor_3': 'Jeremy Irons',
#   'actor_4': 'James Earl Jones',
#   'runtime': '88 min',
#   'votes': '959,898',
#   'gross': '$422.78M',
#   'summary': None},
#  {'rank': '45.',
#   'movie url': 'https://imdb.com/title/tt0103064/',
#   'title': 'Terminator 2: Judgment Day',
#   'date': '1991',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">75        </span>,
#   'genre': 'Action, Sci-Fi',
#   'director': 'James Cameron',
#   'actor_1': 'Arnold Schwarzenegger',
#   'actor_2': 'Linda Hamilton',
#   'actor_3': 'Edward Furlong',
#   'actor_4': 'Robert Patrick',
#   'runtime': '137 min',
#   'votes': '1,009,399',
#   'gross': '$204.84M',
#   'summary': None},
#  {'rank': '46.',
#   'movie url': 'https://imdb.com/title/tt0095765/',
#   'title': 'Nuovo Cinema Paradiso',
#   'date': '1988',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">80        </span>,
#   'genre': 'Drama, Romance',
#   'director': 'Giuseppe Tornatore',
#   'actor_1': 'Philippe Noiret',
#   'actor_2': 'Enzo Cannavale',
#   'actor_3': 'Antonella Attili',
#   'actor_4': 'Isa Danieli',
#   'runtime': '155 min',
#   'votes': '235,993',
#   'gross': '$11.99M',
#   'summary': None},
#  {'rank': '47.',
#   'movie url': 'https://imdb.com/title/tt0095327/',
#   'title': 'Hotaru no haka',
#   'date': '1988',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">94        </span>,
#   'genre': 'Animation, Drama, War',
#   'director': 'Isao Takahata',
#   'actor_1': 'Tsutomu Tatsumi',
#   'actor_2': 'Ayano Shiraishi',
#   'actor_3': 'Akemi Yamaguchi',
#   'actor_4': 'Yoshiko Shinohara',
#   'runtime': '89 min',
#   'votes': '242,386',
#   'gross': 'N/A',
#   'summary': None},
#  {'rank': '48.',
#   'movie url': 'https://imdb.com/title/tt0088763/',
#   'title': 'Terug naar de toekomst',
#   'date': '1985',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">87        </span>,
#   'genre': 'Adventure, Comedy, Sci-Fi',
#   'director': 'Robert Zemeckis',
#   'actor_1': 'Michael J. Fox',
#   'actor_2': 'Christopher Lloyd',
#   'actor_3': 'Lea Thompson',
#   'actor_4': 'Crispin Glover',
#   'runtime': '116 min',
#   'votes': '1,079,824',
#   'gross': '$210.61M',
#   'summary': None},
#  {'rank': '49.',
#   'movie url': 'https://imdb.com/title/tt0064116/',
#   'title': 'Once Upon a Time in the West',
#   'date': '1968',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">80        </span>,
#   'genre': 'Western',
#   'director': 'Sergio Leone',
#   'actor_1': 'Henry Fonda',
#   'actor_2': 'Charles Bronson',
#   'actor_3': 'Claudia Cardinale',
#   'actor_4': 'Jason Robards',
#   'runtime': '165 min',
#   'votes': '307,407',
#   'gross': '$5.32M',
#   'summary': None},
#  {'rank': '50.',
#   'movie url': 'https://imdb.com/title/tt0054215/',
#   'title': 'Psycho',
#   'date': '1960',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">97        </span>,
#   'genre': 'Horror, Mystery, Thriller',
#   'director': 'Alfred Hitchcock',
#   'actor_1': 'Anthony Perkins',
#   'actor_2': 'Janet Leigh',
#   'actor_3': 'Vera Miles',
#   'actor_4': 'John Gavin',
#   'runtime': '109 min',
#   'votes': '614,618',
#   'gross': '$32.00M',
#   'summary': None},
#  {'rank': '51.',
#   'movie url': 'https://imdb.com/title/tt0047396/',
#   'title': 'Rear Window',
#   'date': '1954',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">100        </span>,
#   'genre': 'Mystery, Thriller',
#   'director': 'Alfred Hitchcock',
#   'actor_1': 'James Stewart',
#   'actor_2': 'Grace Kelly',
#   'actor_3': 'Wendell Corey',
#   'actor_4': 'Thelma Ritter',
#   'runtime': '112 min',
#   'votes': '451,295',
#   'gross': '$36.76M',
#   'summary': None},
#  {'rank': '52.',
#   'movie url': 'https://imdb.com/title/tt0034583/',
#   'title': 'Casablanca',
#   'date': '1942',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">100        </span>,
#   'genre': 'Drama, Romance, War',
#   'director': 'Michael Curtiz',
#   'actor_1': 'Humphrey Bogart',
#   'actor_2': 'Ingrid Bergman',
#   'actor_3': 'Paul Henreid',
#   'actor_4': 'Claude Rains',
#   'runtime': '102 min',
#   'votes': '529,842',
#   'gross': '$1.02M',
#   'summary': None},
#  {'rank': '53.',
#   'movie url': 'https://imdb.com/title/tt0027977/',
#   'title': 'Modern Times',
#   'date': '1936',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">96        </span>,
#   'genre': 'Comedy, Drama, Family',
#   'director': 'Charles Chaplin',
#   'actor_1': 'Charles Chaplin',
#   'actor_2': 'Paulette Goddard',
#   'actor_3': 'Henry Bergman',
#   'actor_4': 'Tiny Sandford',
#   'runtime': '87 min',
#   'votes': '222,271',
#   'gross': '$0.16M',
#   'summary': None},
#  {'rank': '54.',
#   'movie url': 'https://imdb.com/title/tt0021749/',
#   'title': 'City Lights',
#   'date': '1931',
#   'IMDb rating': '8.5',
#   'metascore': <span class="metascore favorable">99        </span>,
#   'genre': 'Comedy, Drama, Romance',
#   'director': 'Charles Chaplin',
#   'actor_1': 'Charles Chaplin',
#   'actor_2': 'Virginia Cherrill',
#   'actor_3': 'Florence Lee',
#   'actor_4': 'Harry Myers',
#   'runtime': '87 min',
#   'votes': '170,848',
#   'gross': '$0.02M',
#   'summary': None},
#  {'rank': '55.',
#   'movie url': 'https://imdb.com/title/tt8267604/',
#   'title': 'Capharnaüm',
#   'date': '2018',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">75        </span>,
#   'genre': 'Drama',
#   'director': 'Nadine Labaki',
#   'actor_1': 'Zain Al Rafeea',
#   'actor_2': 'Yordanos Shiferaw',
#   'actor_3': 'Boluwatife Treasure Bankole',
#   'actor_4': 'Kawsar Al Haddad',
#   'runtime': '126 min',
#   'votes': '68,408',
#   'gross': '$1.66M',
#   'summary': None},
#  {'rank': '56.',
#   'movie url': 'https://imdb.com/title/tt7286456/',
#   'title': 'Joker',
#   'date': '2019',
#   'IMDb rating': '8.4',
#   'metascore': None,
#   'genre': 'Crime, Drama, Thriller',
#   'director': 'Todd Phillips',
#   'actor_1': 'Joaquin Phoenix',
#   'actor_2': 'Robert De Niro',
#   'actor_3': 'Zazie Beetz',
#   'actor_4': 'Frances Conroy',
#   'runtime': '122 min',
#   'votes': '993,982',
#   'gross': '$335.45M',
#   'summary': None},
#  {'rank': '57.',
#   'movie url': 'https://imdb.com/title/tt6316138/',
#   'title': 'Ayla: The Daughter of War',
#   'date': '2017',
#   'IMDb rating': '8.4',
#   'metascore': None,
#   'genre': 'Biography, Drama, History',
#   'director': 'Can Ulkay',
#   'actor_1': 'Çetin Tekindor',
#   'actor_2': 'Ismail Hacioglu',
#   'actor_3': 'Kyung-jin Lee',
#   'actor_4': 'Kim Seol',
#   'runtime': '125 min',
#   'votes': '35,426',
#   'gross': 'N/A',
#   'summary': None},
#  {'rank': '58.',
#   'movie url': 'https://imdb.com/title/tt6148156/',
#   'title': 'Vikram Vedha',
#   'date': '2017',
#   'IMDb rating': '8.4',
#   'metascore': None,
#   'genre': 'Action, Crime, Drama',
#   'director': 'Gayatri',
#   'actor_1': 'Pushkar',
#   'actor_2': 'Madhavan',
#   'actor_3': 'Vijay Sethupathi',
#   'actor_4': 'Shraddha Srinath',
#   'runtime': '147 min',
#   'votes': '30,028',
#   'gross': 'N/A',
#   'summary': None},
#  {'rank': '59.',
#   'movie url': 'https://imdb.com/title/tt5311514/',
#   'title': 'Kimi no na wa.',
#   'date': '2016',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">79        </span>,
#   'genre': 'Animation, Drama, Fantasy',
#   'director': 'Makoto Shinkai',
#   'actor_1': 'Ryûnosuke Kamiki',
#   'actor_2': 'Mone Kamishiraishi',
#   'actor_3': 'Ryô Narita',
#   'actor_4': 'Aoi Yûki',
#   'runtime': '106 min',
#   'votes': '207,692',
#   'gross': '$5.02M',
#   'summary': None},
#  {'rank': '60.',
#   'movie url': 'https://imdb.com/title/tt5074352/',
#   'title': 'Dangal',
#   'date': '2016',
#   'IMDb rating': '8.4',
#   'metascore': None,
#   'genre': 'Action, Biography, Drama',
#   'director': 'Nitesh Tiwari',
#   'actor_1': 'Aamir Khan',
#   'actor_2': 'Sakshi Tanwar',
#   'actor_3': 'Fatima Sana Shaikh',
#   'actor_4': 'Sanya Malhotra',
#   'runtime': '161 min',
#   'votes': '162,138',
#   'gross': '$12.39M',
#   'summary': None},
#  {'rank': '61.',
#   'movie url': 'https://imdb.com/title/tt4633694/',
#   'title': 'Spider-Man: Een nieuw universum',
#   'date': '2018',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">87        </span>,
#   'genre': 'Animation, Action, Adventure',
#   'director': 'Bob Persichetti',
#   'actor_1': 'Peter Ramsey',
#   'actor_2': 'Rodney Rothman',
#   'actor_3': 'Shameik Moore',
#   'actor_4': 'Jake Johnson',
#   'runtime': '117 min',
#   'votes': '398,046',
#   'gross': '$190.24M',
#   'summary': None},
#  {'rank': '62.',
#   'movie url': 'https://imdb.com/title/tt4154796/',
#   'title': 'Avengers: Endgame',
#   'date': '2019',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">78        </span>,
#   'genre': 'Action, Adventure, Drama',
#   'director': 'Anthony Russo',
#   'actor_1': 'Joe Russo',
#   'actor_2': 'Robert Downey Jr.',
#   'actor_3': 'Chris Evans',
#   'actor_4': 'Mark Ruffalo',
#   'runtime': '181 min',
#   'votes': '869,547',
#   'gross': '$858.37M',
#   'summary': None},
#  {'rank': '63.',
#   'movie url': 'https://imdb.com/title/tt4154756/',
#   'title': 'Avengers: Infinity War',
#   'date': '2018',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">68        </span>,
#   'genre': 'Action, Adventure, Sci-Fi',
#   'director': 'Anthony Russo',
#   'actor_1': 'Joe Russo',
#   'actor_2': 'Robert Downey Jr.',
#   'actor_3': 'Chris Hemsworth',
#   'actor_4': 'Mark Ruffalo',
#   'runtime': '149 min',
#   'votes': '874,232',
#   'gross': '$678.82M',
#   'summary': None},
#  {'rank': '64.',
#   'movie url': 'https://imdb.com/title/tt2380307/',
#   'title': 'Coco',
#   'date': 'I 2017',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">81        </span>,
#   'genre': 'Animation, Adventure, Family',
#   'director': 'Lee Unkrich',
#   'actor_1': 'Adrian Molina',
#   'actor_2': 'Anthony Gonzalez',
#   'actor_3': 'Gael García Bernal',
#   'actor_4': 'Benjamin Bratt',
#   'runtime': '105 min',
#   'votes': '403,927',
#   'gross': '$209.73M',
#   'summary': None},
#  {'rank': '65.',
#   'movie url': 'https://imdb.com/title/tt1853728/',
#   'title': 'Django Unchained',
#   'date': '2012',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">81        </span>,
#   'genre': 'Drama, Western',
#   'director': 'Quentin Tarantino',
#   'actor_1': 'Jamie Foxx',
#   'actor_2': 'Christoph Waltz',
#   'actor_3': 'Leonardo DiCaprio',
#   'actor_4': 'Kerry Washington',
#   'runtime': '165 min',
#   'votes': '1,386,570',
#   'gross': '$162.81M',
#   'summary': None},
#  {'rank': '66.',
#   'movie url': 'https://imdb.com/title/tt1345836/',
#   'title': 'The Dark Knight Rises',
#   'date': '2012',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">78        </span>,
#   'genre': 'Action, Adventure',
#   'director': 'Christopher Nolan',
#   'actor_1': 'Christian Bale',
#   'actor_2': 'Tom Hardy',
#   'actor_3': 'Anne Hathaway',
#   'actor_4': 'Gary Oldman',
#   'runtime': '164 min',
#   'votes': '1,542,685',
#   'gross': '$448.14M',
#   'summary': None},
#  {'rank': '67.',
#   'movie url': 'https://imdb.com/title/tt1187043/',
#   'title': '3 Idiots',
#   'date': '2009',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">67        </span>,
#   'genre': 'Comedy, Drama',
#   'director': 'Rajkumar Hirani',
#   'actor_1': 'Aamir Khan',
#   'actor_2': 'Madhavan',
#   'actor_3': 'Mona Singh',
#   'actor_4': 'Sharman Joshi',
#   'runtime': '170 min',
#   'votes': '352,911',
#   'gross': '$6.53M',
#   'summary': None},
#  {'rank': '68.',
#   'movie url': 'https://imdb.com/title/tt0986264/',
#   'title': 'Taare Zameen Par',
#   'date': '2007',
#   'IMDb rating': '8.4',
#   'metascore': None,
#   'genre': 'Drama, Family',
#   'director': 'Aamir Khan',
#   'actor_1': 'Amole Gupte',
#   'actor_2': 'Darsheel Safary',
#   'actor_3': 'Aamir Khan',
#   'actor_4': 'Tisca Chopra',
#   'runtime': '165 min',
#   'votes': '173,772',
#   'gross': '$1.22M',
#   'summary': None},
#  {'rank': '69.',
#   'movie url': 'https://imdb.com/title/tt0910970/',
#   'title': 'WALL·E',
#   'date': '2008',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">95        </span>,
#   'genre': 'Animation, Adventure, Family',
#   'director': 'Andrew Stanton',
#   'actor_1': 'Ben Burtt',
#   'actor_2': 'Elissa Knight',
#   'actor_3': 'Jeff Garlin',
#   'actor_4': 'Fred Willard',
#   'runtime': '98 min',
#   'votes': '1,017,546',
#   'gross': '$223.81M',
#   'summary': None},
#  {'rank': '70.',
#   'movie url': 'https://imdb.com/title/tt0405094/',
#   'title': 'Das Leben der Anderen',
#   'date': '2006',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">89        </span>,
#   'genre': 'Drama, Mystery, Thriller',
#   'director': 'Florian Henckel von Donnersmarck',
#   'actor_1': 'Ulrich Mühe',
#   'actor_2': 'Martina Gedeck',
#   'actor_3': 'Sebastian Koch',
#   'actor_4': 'Ulrich Tukur',
#   'runtime': '137 min',
#   'votes': '364,863',
#   'gross': '$11.29M',
#   'summary': None},
#  {'rank': '71.',
#   'movie url': 'https://imdb.com/title/tt0364569/',
#   'title': 'Oldeuboi',
#   'date': '2003',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">77        </span>,
#   'genre': 'Action, Drama, Mystery',
#   'director': 'Chan-wook Park',
#   'actor_1': 'Choi Min-sik',
#   'actor_2': 'Yoo Ji-Tae',
#   'actor_3': 'Kang Hye-jeong',
#   'actor_4': 'Kim Byeong-Ok',
#   'runtime': '120 min',
#   'votes': '525,955',
#   'gross': '$0.71M',
#   'summary': None},
#  {'rank': '72.',
#   'movie url': 'https://imdb.com/title/tt0209144/',
#   'title': 'Memento',
#   'date': '2000',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">80        </span>,
#   'genre': 'Mystery, Thriller',
#   'director': 'Christopher Nolan',
#   'actor_1': 'Guy Pearce',
#   'actor_2': 'Carrie-Anne Moss',
#   'actor_3': 'Joe Pantoliano',
#   'actor_4': 'Mark Boone Junior',
#   'runtime': '113 min',
#   'votes': '1,143,261',
#   'gross': '$25.54M',
#   'summary': None},
#  {'rank': '73.',
#   'movie url': 'https://imdb.com/title/tt0119698/',
#   'title': 'Mononoke-hime',
#   'date': '1997',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">76        </span>,
#   'genre': 'Animation, Action, Adventure',
#   'director': 'Hayao Miyazaki',
#   'actor_1': 'Yôji Matsuda',
#   'actor_2': 'Yuriko Ishida',
#   'actor_3': 'Yûko Tanaka',
#   'actor_4': 'Billy Crudup',
#   'runtime': '134 min',
#   'votes': '351,870',
#   'gross': '$2.38M',
#   'summary': None},
#  {'rank': '74.',
#   'movie url': 'https://imdb.com/title/tt0087843/',
#   'title': 'Once Upon a Time in America',
#   'date': '1984',
#   'IMDb rating': '8.4',
#   'metascore': None,
#   'genre': 'Crime, Drama',
#   'director': 'Sergio Leone',
#   'actor_1': 'Robert De Niro',
#   'actor_2': 'James Woods',
#   'actor_3': 'Elizabeth McGovern',
#   'actor_4': 'Treat Williams',
#   'runtime': '229 min',
#   'votes': '317,681',
#   'gross': '$5.32M',
#   'summary': None},
#  {'rank': '75.',
#   'movie url': 'https://imdb.com/title/tt0082971/',
#   'title': 'Indiana Jones and the Raiders of the Lost Ark',
#   'date': '1981',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">85        </span>,
#   'genre': 'Action, Adventure',
#   'director': 'Steven Spielberg',
#   'actor_1': 'Harrison Ford',
#   'actor_2': 'Karen Allen',
#   'actor_3': 'Paul Freeman',
#   'actor_4': 'John Rhys-Davies',
#   'runtime': '115 min',
#   'votes': '896,210',
#   'gross': '$248.16M',
#   'summary': None},
#  {'rank': '76.',
#   'movie url': 'https://imdb.com/title/tt0081505/',
#   'title': 'The Shining',
#   'date': '1980',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">66        </span>,
#   'genre': 'Drama, Horror',
#   'director': 'Stanley Kubrick',
#   'actor_1': 'Jack Nicholson',
#   'actor_2': 'Shelley Duvall',
#   'actor_3': 'Danny Lloyd',
#   'actor_4': 'Scatman Crothers',
#   'runtime': '146 min',
#   'votes': '915,826',
#   'gross': '$44.02M',
#   'summary': None},
#  {'rank': '77.',
#   'movie url': 'https://imdb.com/title/tt0078788/',
#   'title': 'Apocalypse Now',
#   'date': '1979',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">94        </span>,
#   'genre': 'Drama, Mystery, War',
#   'director': 'Francis Ford Coppola',
#   'actor_1': 'Martin Sheen',
#   'actor_2': 'Marlon Brando',
#   'actor_3': 'Robert Duvall',
#   'actor_4': 'Frederic Forrest',
#   'runtime': '147 min',
#   'votes': '616,436',
#   'gross': '$83.47M',
#   'summary': None},
#  {'rank': '78.',
#   'movie url': 'https://imdb.com/title/tt0078748/',
#   'title': 'Alien',
#   'date': '1979',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">89        </span>,
#   'genre': 'Horror, Sci-Fi',
#   'director': 'Ridley Scott',
#   'actor_1': 'Sigourney Weaver',
#   'actor_2': 'Tom Skerritt',
#   'actor_3': 'John Hurt',
#   'actor_4': 'Veronica Cartwright',
#   'runtime': '117 min',
#   'votes': '801,713',
#   'gross': '$78.90M',
#   'summary': None},
#  {'rank': '79.',
#   'movie url': 'https://imdb.com/title/tt0057565/',
#   'title': 'Tengoku to jigoku',
#   'date': '1963',
#   'IMDb rating': '8.4',
#   'metascore': None,
#   'genre': 'Crime, Drama, Mystery',
#   'director': 'Akira Kurosawa',
#   'actor_1': 'Toshirô Mifune',
#   'actor_2': 'Yutaka Sada',
#   'actor_3': 'Tatsuya Nakadai',
#   'actor_4': 'Kyôko Kagawa',
#   'runtime': '143 min',
#   'votes': '36,385',
#   'gross': 'N/A',
#   'summary': None},
#  {'rank': '80.',
#   'movie url': 'https://imdb.com/title/tt0057012/',
#   'title': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   'date': '1964',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">97        </span>,
#   'genre': 'Comedy',
#   'director': 'Stanley Kubrick',
#   'actor_1': 'Peter Sellers',
#   'actor_2': 'George C. Scott',
#   'actor_3': 'Sterling Hayden',
#   'actor_4': 'Keenan Wynn',
#   'runtime': '95 min',
#   'votes': '456,772',
#   'gross': '$0.28M',
#   'summary': None},
#  {'rank': '81.',
#   'movie url': 'https://imdb.com/title/tt0051201/',
#   'title': 'Witness for the Prosecution',
#   'date': '1957',
#   'IMDb rating': '8.4',
#   'metascore': None,
#   'genre': 'Crime, Drama, Mystery',
#   'director': 'Billy Wilder',
#   'actor_1': 'Tyrone Power',
#   'actor_2': 'Marlene Dietrich',
#   'actor_3': 'Charles Laughton',
#   'actor_4': 'Elsa Lanchester',
#   'runtime': '116 min',
#   'votes': '111,646',
#   'gross': '$8.18M',
#   'summary': None},
#  {'rank': '82.',
#   'movie url': 'https://imdb.com/title/tt0050825/',
#   'title': 'Het veld van eer',
#   'date': '1957',
#   'IMDb rating': '8.4',
#   'metascore': <span class="metascore favorable">90        </span>,
#   'genre': 'Drama, War',
#   'director': 'Stanley Kubrick',
#   'actor_1': 'Kirk Douglas',
#   'actor_2': 'Ralph Meeker',
#   'actor_3': 'Adolphe Menjou',
#   'actor_4': 'George Macready',
#   'runtime': '88 min',
#   'votes': '181,670',
#   'gross': 'N/A',
#   'summary': None},
#  {'rank': '83.',
#   'movie url': 'https://imdb.com/title/tt0043014/',
#   'title': 'Sunset Boulevard',
#   'date': '1950',
#   'IMDb rating': '8.4',
#   'metascore': None,
#   'genre': 'Drama, Film-Noir',
#   'director': 'Billy Wilder',
#   'actor_1': 'William Holden',
#   'actor_2': 'Gloria Swanson',
#   'actor_3': 'Erich von Stroheim',
#   'actor_4': 'Nancy Olson',
#   'runtime': '110 min',
#   'votes': '205,024',
#   'gross': 'N/A',
#   'summary': None},
#  {'rank': '84.',
#   'movie url': 'https://imdb.com/title/tt0032553/',
#   'title': 'De dictator',
#   'date': '1940',
#   'IMDb rating': '8.4',
#   'metascore': None,
#   'genre': 'Comedy, Drama, War',
#   'director': 'Charles Chaplin',
#   'actor_1': 'Charles Chaplin',
#   'actor_2': 'Paulette Goddard',
#   'actor_3': 'Jack Oakie',
#   'actor_4': 'Reginald Gardiner',
#   'runtime': '125 min',
#   'votes': '206,584',
#   'gross': '$0.29M',
#   'summary': None},
#  {'rank': '85.',
#   'movie url': 'https://imdb.com/title/tt9052870/',
#   'title': 'Chhichhore',
#   'date': '2019',
#   'IMDb rating': '8.3',
#   'metascore': None,
#   'genre': 'Comedy, Drama',
#   'director': 'Nitesh Tiwari',
#   'actor_1': 'Sushant Singh Rajput',
#   'actor_2': 'Shraddha Kapoor',
#   'actor_3': 'Varun Sharma',
#   'actor_4': 'Prateik',
#   'runtime': '143 min',
#   'votes': '35,946',
#   'gross': '$0.90M',
#   'summary': None},
#  {'rank': '86.',
#   'movie url': 'https://imdb.com/title/tt8579674/',
#   'title': '1917',
#   'date': '2019',
#   'IMDb rating': '8.3',
#   'metascore': <span class="metascore favorable">78        </span>,
#   'genre': 'Drama, Thriller, War',
#   'director': 'Sam Mendes',
#   'actor_1': 'Dean-Charles Chapman',
#   'actor_2': 'George MacKay',
#   'actor_3': 'Daniel Mays',
#   'actor_4': 'Colin Firth',
#   'runtime': '119 min',
#   'votes': '458,447',
#   'gross': '$159.23M',
#   'summary': None},
#  {'rank': '87.',
#   'movie url': 'https://imdb.com/title/tt8239946/',
#   'title': 'Tumbbad',
#   'date': '2018',
#   'IMDb rating': '8.3',
#   'metascore': None,
#   'genre': 'Drama, Fantasy, Horror',
#   'director': 'Rahi Anil Barve',
#   'actor_1': 'Anand Gandhi',
#   'actor_2': 'Adesh Prasad',
#   'actor_3': 'Sohum Shah',
#   'actor_4': 'Jyoti Malshe',
#   'runtime': '104 min',
#   'votes': '30,381',
#   'gross': 'N/A',
#   'summary': None},
#  {'rank': '88.',
#   'movie url': 'https://imdb.com/title/tt3417422/',
#   'title': 'Drishyam',
#   'date': '2013',
#   'IMDb rating': '8.3',
#   'metascore': None,
#   'genre': 'Crime, Drama, Thriller',
#   'director': 'Jeethu Joseph',
#   'actor_1': 'Mohanlal',
#   'actor_2': 'Meena',
#   'actor_3': 'Asha Sharath',
#   'actor_4': 'Ansiba',
#   'runtime': '160 min',
#   'votes': '35,085',
#   'gross': 'N/A',
#   'summary': None},
#  {'rank': '89.',
#   'movie url': 'https://imdb.com/title/tt2106476/',
#   'title': 'Jagten',
#   'date': '2012',
#   'IMDb rating': '8.3',
#   'metascore': <span class="metascore favorable">77        </span>,
#   'genre': 'Drama',
#   'director': 'Thomas Vinterberg',
#   'actor_1': 'Mads Mikkelsen',
#   'actor_2': 'Thomas Bo Larsen',
#   'actor_3': 'Annika Wedderkopp',
#   'actor_4': 'Lasse Fogelstrøm',
#   'runtime': '115 min',
#   'votes': '291,467',
#   'gross': '$0.69M',
#   'summary': None},
#  {'rank': '90.',
#   'movie url': 'https://imdb.com/title/tt1832382/',
#   'title': 'A Separation',
#   'date': '2011',
#   'IMDb rating': '8.3',
#   'metascore': <span class="metascore favorable">95        </span>,
#   'genre': 'Drama',
#   'director': 'Asghar Farhadi',
#   'actor_1': 'Payman Maadi',
#   'actor_2': 'Leila Hatami',
#   'actor_3': 'Sareh Bayat',
#   'actor_4': 'Shahab Hosseini',
#   'runtime': '123 min',
#   'votes': '224,747',
#   'gross': '$7.10M',
#   'summary': None},
#  {'rank': '91.',
#   'movie url': 'https://imdb.com/title/tt1255953/',
#   'title': 'Incendies',
#   'date': '2010',
#   'IMDb rating': '8.3',
#   'metascore': <span class="metascore favorable">80        </span>,
#   'genre': 'Drama, Mystery, War',
#   'director': 'Denis Villeneuve',
#   'actor_1': 'Lubna Azabal',
#   'actor_2': 'Mélissa Désormeaux-Poulin',
#   'actor_3': 'Maxim Gaudette',
#   'actor_4': 'Mustafa Kamel',
#   'runtime': '131 min',
#   'votes': '154,931',
#   'gross': '$6.86M',
#   'summary': None},
#  {'rank': '92.',
#   'movie url': 'https://imdb.com/title/tt10554232/',
#   'title': 'Dara iz Jasenovca',
#   'date': '2020',
#   'IMDb rating': '8.3',
#   'metascore': None,
#   'genre': 'Drama, War',
#   'director': 'Predrag Antonijevic',
#   'actor_1': 'Biljana Cekic',
#   'actor_2': 'Zlatan Vidovic',
#   'actor_3': 'Anja Stanic',
#   'actor_4': 'Luka Saranovic',
#   'runtime': '130 min',
#   'votes': '34,418',
#   'gross': 'N/A',
#   'summary': None},
#  {'rank': '93.',
#   'movie url': 'https://imdb.com/title/tt10272386/',
#   'title': 'The Father',
#   'date': 'I 2020',
#   'IMDb rating': '8.3',
#   'metascore': <span class="metascore favorable">88        </span>,
#   'genre': 'Drama',
#   'director': 'Florian Zeller',
#   'actor_1': 'Anthony Hopkins',
#   'actor_2': 'Olivia Colman',
#   'actor_3': 'Mark Gatiss',
#   'actor_4': 'Olivia Williams',
#   'runtime': '97 min',
#   'votes': '54,778',
#   'gross': 'N/A',
#   'summary': None},
#  {'rank': '94.',
#   'movie url': 'https://imdb.com/title/tt0476735/',
#   'title': 'Babam ve Oglum',
#   'date': '2005',
#   'IMDb rating': '8.3',
#   'metascore': None,
#   'genre': 'Drama, Family',
#   'director': 'Cagan Irmak',
#   'actor_1': 'Eser Sariyar',
#   'actor_2': 'Çetin Tekindor',
#   'actor_3': 'Fikret Kuskan',
#   'actor_4': 'Hümeyra',
#   'runtime': '112 min',
#   'votes': '80,759',
#   'gross': 'N/A',
#   'summary': None},
#  {'rank': '95.',
#   'movie url': 'https://imdb.com/title/tt0361748/',
#   'title': 'Inglourious Basterds',
#   'date': '2009',
#   'IMDb rating': '8.3',
#   'metascore': <span class="metascore favorable">69        </span>,
#   'genre': 'Adventure, Drama, War',
#   'director': 'Quentin Tarantino',
#   'actor_1': 'Brad Pitt',
#   'actor_2': 'Diane Kruger',
#   'actor_3': 'Eli Roth',
#   'actor_4': 'Mélanie Laurent',
#   'runtime': '153 min',
#   'votes': '1,295,372',
#   'gross': '$120.54M',
#   'summary': None},
#  {'rank': '96.',
#   'movie url': 'https://imdb.com/title/tt0338013/',
#   'title': 'Eternal Sunshine of the Spotless Mind',
#   'date': '2004',
#   'IMDb rating': '8.3',
#   'metascore': <span class="metascore favorable">89        </span>,
#   'genre': 'Drama, Romance, Sci-Fi',
#   'director': 'Michel Gondry',
#   'actor_1': 'Jim Carrey',
#   'actor_2': 'Kate Winslet',
#   'actor_3': 'Tom Wilkinson',
#   'actor_4': 'Gerry Robert Byrne',
#   'runtime': '108 min',
#   'votes': '925,899',
#   'gross': '$34.40M',
#   'summary': None},
#  {'rank': '97.',
#   'movie url': 'https://imdb.com/title/tt0211915/',
#   'title': 'Amélie',
#   'date': '2001',
#   'IMDb rating': '8.3',
#   'metascore': <span class="metascore favorable">69        </span>,
#   'genre': 'Comedy, Romance',
#   'director': 'Jean-Pierre Jeunet',
#   'actor_1': 'Audrey Tautou',
#   'actor_2': 'Mathieu Kassovitz',
#   'actor_3': 'Rufus',
#   'actor_4': 'Lorella Cravotta',
#   'runtime': '122 min',
#   'votes': '712,859',
#   'gross': '$33.23M',
#   'summary': None},
#  {'rank': '98.',
#   'movie url': 'https://imdb.com/title/tt0208092/',
#   'title': 'Snatch',
#   'date': '2000',
#   'IMDb rating': '8.3',
#   'metascore': None,
#   'genre': 'Comedy, Crime',
#   'director': 'Guy Ritchie',
#   'actor_1': 'Jason Statham',
#   'actor_2': 'Brad Pitt',
#   'actor_3': 'Benicio Del Toro',
#   'actor_4': 'Dennis Farina',
#   'runtime': '104 min',
#   'votes': '793,411',
#   'gross': '$30.33M',
#   'summary': None},
#  {'rank': '99.',
#   'movie url': 'https://imdb.com/title/tt0180093/',
#   'title': 'Requiem for a Dream',
#   'date': '2000',
#   'IMDb rating': '8.3',
#   'metascore': <span class="metascore favorable">68        </span>,
#   'genre': 'Drama',
#   'director': 'Darren Aronofsky',
#   'actor_1': 'Ellen Burstyn',
#   'actor_2': 'Jared Leto',
#   'actor_3': 'Jennifer Connelly',
#   'actor_4': 'Marlon Wayans',
#   'runtime': '102 min',
#   'votes': '779,048',
#   'gross': '$3.64M',
#   'summary': None},
#  {'rank': '100.',
#   'movie url': 'https://imdb.com/title/tt0169547/',
#   'title': 'American Beauty',
#   'date': '1999',
#   'IMDb rating': '8.3',
#   'metascore': <span class="metascore favorable">84        </span>,
#   'genre': 'Drama',
#   'director': 'Sam Mendes',
#   'actor_1': 'Kevin Spacey',
#   'actor_2': 'Annette Bening',
#   'actor_3': 'Thora Birch',
#   'actor_4': 'Wes Bentley',
#   'runtime': '122 min',
#   'votes': '1,083,681',
#   'gross': '$130.10M',
#   'summary': None}]

# %% [markdown]
# ## Create dataframe

# %%
movie_dataframe = pd.DataFrame(movie_list)
movie_dataframe.to_csv("IMDb_top1000_dataframe.csv", index=False)
movie_dataframe
# Out:
#     rank                           movie url  \
# 0     1.   https://imdb.com/title/tt0111161/
# 1     2.   https://imdb.com/title/tt0068646/
# 2     3.  https://imdb.com/title/tt10189514/
# 3     4.   https://imdb.com/title/tt0468569/
# 4     5.   https://imdb.com/title/tt0071562/
# ..   ...                                 ...
# 95   96.   https://imdb.com/title/tt0338013/
# 96   97.   https://imdb.com/title/tt0211915/
# 97   98.   https://imdb.com/title/tt0208092/
# 98   99.   https://imdb.com/title/tt0180093/
# 99  100.   https://imdb.com/title/tt0169547/
#
#                                     title  date IMDb rating      metascore  \
# 0                The Shawshank Redemption  1994         9.3   [80        ]
# 1                           The Godfather  1972         9.2  [100        ]
# 2                         Soorarai Pottru  2020         9.1           None
# 3                         The Dark Knight  2008         9.0   [84        ]
# 4                  The Godfather: Part II  1974         9.0   [90        ]
# ..                                    ...   ...         ...            ...
# 95  Eternal Sunshine of the Spotless Mind  2004         8.3   [89        ]
# 96                                 Amélie  2001         8.3   [69        ]
# 97                                 Snatch  2000         8.3           None
# 98                    Requiem for a Dream  2000         8.3   [68        ]
# 99                        American Beauty  1999         8.3   [84        ]
#
#                      genre              director         actor_1  \
# 0                    Drama        Frank Darabont     Tim Robbins
# 1             Crime, Drama  Francis Ford Coppola   Marlon Brando
# 2                    Drama         Sudha Kongara          Suriya
# 3     Action, Crime, Drama     Christopher Nolan  Christian Bale
# 4             Crime, Drama  Francis Ford Coppola       Al Pacino
# ..                     ...                   ...             ...
# 95  Drama, Romance, Sci-Fi         Michel Gondry      Jim Carrey
# 96         Comedy, Romance    Jean-Pierre Jeunet   Audrey Tautou
# 97           Comedy, Crime           Guy Ritchie   Jason Statham
# 98                   Drama      Darren Aronofsky   Ellen Burstyn
# 99                   Drama            Sam Mendes    Kevin Spacey
#
#               actor_2            actor_3             actor_4  runtime  \
# 0      Morgan Freeman         Bob Gunton      William Sadler  142 min
# 1           Al Pacino         James Caan        Diane Keaton  175 min
# 2            Madhavan       Paresh Rawal   Aparna Balamurali  153 min
# 3        Heath Ledger      Aaron Eckhart       Michael Caine  152 min
# 4      Robert De Niro      Robert Duvall        Diane Keaton  202 min
# ..                ...                ...                 ...      ...
# 95       Kate Winslet      Tom Wilkinson  Gerry Robert Byrne  108 min
# 96  Mathieu Kassovitz              Rufus    Lorella Cravotta  122 min
# 97          Brad Pitt   Benicio Del Toro       Dennis Farina  104 min
# 98         Jared Leto  Jennifer Connelly       Marlon Wayans  102 min
# 99     Annette Bening        Thora Birch         Wes Bentley  122 min
#
#         votes     gross summary
# 0   2,388,501   $28.34M    None
# 1   1,655,142  $134.97M    None
# 2      60,614       N/A    None
# 3   2,351,178  $534.86M    None
# 4   1,151,039   $57.30M    None
# ..        ...       ...     ...
# 95    925,899   $34.40M    None
# 96    712,859   $33.23M    None
# 97    793,411   $30.33M    None
# 98    779,048    $3.64M    None
# 99  1,083,681  $130.10M    None
#
# [100 rows x 16 columns]
